# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

# %%
suggested
# Out:
#         dimension_1   dimension_2                 imp_1                 imp_2  \
# 0          accuracy  completeness       impute_standard       impute_standard
# 1          accuracy  completeness         impute_median         impute_median
# 2          accuracy  completeness         impute_median         impute_median
# 3          accuracy  completeness       impute_standard       impute_standard
# 4      completeness      accuracy       impute_standard       impute_standard
# ...             ...           ...                   ...                   ...
# 30235      accuracy  completeness           impute_mice  impute_random_forest
# 30236      accuracy  completeness            impute_knn         impute_median
# 30237      accuracy  completeness  impute_random_forest       impute_standard
# 30238  completeness      accuracy       impute_standard       impute_standard
# 30239      accuracy  completeness       impute_standard            impute_knn
#
#                  imp_3            imp_4            imp_5  \
# 0      impute_standard  impute_standard  impute_standard
# 1        impute_median    impute_median    impute_median
# 2        impute_median    impute_median    impute_median
# 3      impute_standard  impute_standard  impute_standard
# 4      impute_standard  impute_standard  impute_standard
# ...                ...              ...              ...
# 30235    impute_median    impute_median    impute_median
# 30236    impute_median    impute_median    impute_median
# 30237  impute_standard  impute_standard  impute_standard
# 30238  impute_standard  impute_standard  impute_standard
# 30239       impute_knn       impute_knn       impute_knn
#
#                       imp_6                 imp_7 od_1  ...  imp_col_2  \
# 0           impute_standard            impute_knn  IQR  ...        RAM
# 1      impute_random_forest           impute_mice  IQR  ...        RAM
# 2             impute_median            impute_knn  IQR  ...        RAM
# 3           impute_standard  impute_random_forest  IQR  ...        RAM
# 4           impute_standard       impute_standard  IQR  ...        RAM
# ...                     ...                   ...  ...  ...        ...
# 30235         impute_median         impute_median  IQR  ...  Selfi_Cam
# 30236         impute_median         impute_median  IQR  ...  Selfi_Cam
# 30237       impute_standard       impute_standard  IQR  ...  Selfi_Cam
# 30238       impute_standard       impute_standard  IQR  ...  Selfi_Cam
# 30239            impute_knn            impute_knn  IQR  ...  Selfi_Cam
#
#          imp_col_3    imp_col_4    imp_col_5  imp_col_6      imp_col_7  \
# 0              ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# 1              ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# 2              ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# 3              ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# 4              ROM  Mobile_Size  Primary_Cam  Selfi_Cam  Battery_Power
# ...            ...          ...          ...        ...            ...
# 30235  Primary_Cam  Mobile_Size          ROM        RAM        Ratings
# 30236  Primary_Cam  Mobile_Size          ROM        RAM        Ratings
# 30237  Primary_Cam  Mobile_Size          ROM        RAM        Ratings
# 30238  Primary_Cam  Mobile_Size          ROM        RAM        Ratings
# 30239  Primary_Cam  Mobile_Size          ROM        RAM        Ratings
#
#                 algorithm perf_dirty    perf_1    perf_2
# 0            DecisionTree   0.870917  0.878272  0.880308
# 1      LogisticRegression   0.704135  0.721778  0.708826
# 2                     KNN   0.811467  0.813895  0.767232
# 3            RandomForest   0.886566  0.884364  0.897873
# 4                AdaBoost   0.651450  0.674883  0.720518
# ...                   ...        ...       ...       ...
# 30235  LogisticRegression   0.694272  0.735552  0.711537
# 30236                 KNN   0.841439  0.826661  0.783830
# 30237        RandomForest   0.877195  0.857518  0.883728
# 30238            AdaBoost   0.646812  0.668130  0.593631
# 30239                 SVC   0.736865  0.785915  0.798736
#
# [30240 rows x 27 columns]

# %%
models = ['DecisionTree','LogisticRegression','KNN','RandomForest','AdaBoost','SVC']

# %%
models = ['LogisticRegression']

# %%
for algorithm in models:

    sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
    suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

    suggested = suggested[suggested.algorithm == algorithm]
    sample = sample[['dimension_1', 'dimension_2', 'imp_1', 'imp_2', 'imp_3', 'imp_4',
           'imp_5', 'imp_6', 'imp_7', 'od_1', 'od_2', 'od_3', 'od_4', 'od_5',
           'od_6', 'od_7', 'imp_col_1', 'imp_col_2', 'imp_col_3', 'imp_col_4',
           'imp_col_5', 'imp_col_6', 'imp_col_7', algorithm + '_dirty', algorithm + '_1', algorithm + '_2']]

    original_perf = {
            'DecisionTree': 0.8730314885952215,
            'LogisticRegression': 0.7166503552028867,
            'KNN': 0.81529491393676,
            'RandomForest': 0.8975431406130385,
            'AdaBoost': 0.6669934606506549,
            'SVC': 0.7537471482401658
        }

    x = [sample[algorithm + '_2']]
    y = [suggested.perf_2]

    plt.title(algorithm)

    plt.hist(x, label='ALL', color='royalblue')
    plt.hist(y, label='SUGGESTED', color='red')

    plt.axvline(x=np.median(y), color='red', label='median suggested')
    plt.axvline(x=np.median(x), color='black', label='median all')

    #plt.axvline(x=np.percentile(y, 25), color='red', label='1Q suggested', linestyle='dashed')
    #plt.axvline(x=np.percentile(x, 25), color='black', label='1Q all', linestyle='dashed')

    #plt.axvline(x=np.percentile(y, 75), color='red', label='3Q suggested', linestyle='dashed')
    #plt.axvline(x=np.percentile(x, 75), color='black', label='3Q all', linestyle='dashed')

    plt.axvline(x=original_perf[algorithm], color='darkorange', label='dirty')

    #plt.legend(loc='upper right')
    plt.ylim(0,120000)

    plt.savefig("/Users/camillasancricca/Desktop/" + algorithm + "mobile.pdf", bbox_inches='tight')
    plt.show()

# %%
for algorithm in models:

    sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
    suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

    suggested = suggested[suggested.algorithm == algorithm]
    sample = sample[['dimension_1', 'dimension_2', 'imp_1', 'imp_2', 'imp_3', 'imp_4',
           'imp_5', 'imp_6', 'imp_7', 'od_1', 'od_2', 'od_3', 'od_4', 'od_5',
           'od_6', 'od_7', 'imp_col_1', 'imp_col_2', 'imp_col_3', 'imp_col_4',
           'imp_col_5', 'imp_col_6', 'imp_col_7', algorithm + '_dirty', algorithm + '_1', algorithm + '_2']]

    original_perf = {
            'DecisionTree': 0.8730314885952215,
            'LogisticRegression': 0.7166503552028867,
            'KNN': 0.81529491393676,
            'RandomForest': 0.8975431406130385,
            'AdaBoost': 0.6669934606506549,
            'SVC': 0.7537471482401658
        }

    x = [sample[algorithm + '_2']]
    y = [suggested.perf_2]

    plt.title(algorithm)

    plt.hist(x, label='ALL', color='royalblue')
    plt.hist(y, label='SUGGESTED', color='red')

    plt.axvline(x=np.median(y), color='red', label='median suggested')
    plt.axvline(x=np.median(x), color='black', label='median all')

    plt.axvline(x=np.percentile(y, 25), color='red', label='1Q suggested', linestyle='dashed')
    plt.axvline(x=np.percentile(x, 25), color='black', label='1Q all', linestyle='dashed')

    plt.axvline(x=np.percentile(y, 75), color='red', label='3Q suggested', linestyle='dashed')
    plt.axvline(x=np.percentile(x, 75), color='black', label='3Q all', linestyle='dashed')

    #plt.axvline(x=original_perf[algorithm], color='darkorange', label='dirty')

    plt.legend(loc='upper right')
    plt.savefig("/Users/camillasancricca/Desktop/" + algorithm + "2.png", bbox_inches='tight')
    plt.show()
