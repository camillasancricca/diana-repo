# %%
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sb

# %%
df = pd.read_csv("scripts/KBA.csv")

# %%
columns_X = ['n_tuples', 'uniqueness', 'min', 'max',
       'mean', 'median', 'std', 'skewness', 'kurtosis', 'mad', 'iqr', 'p_min',
       'p_max', 'k_min', 'k_max', 's_min', 's_max', 'entropy', 'density',
       'percentage_outliers', 'std_outliers']

dataplot = sb.heatmap(df[columns_X].corr(), cmap="YlGnBu")
mp.show()

# %%
columns_profile = ['min', 'max', 'mean', 'median', 'std', 'percentage_outliers','std_outliers']
dataplot = sb.heatmap(df[columns_profile].corr(), cmap="YlGnBu")
mp.show()

# %%
### std_outliers non è molto correlato con std della colonna

# %%
### l'errore è un po' puù alto se non considero std_outliers ma dovrebbe essere comparabile...
