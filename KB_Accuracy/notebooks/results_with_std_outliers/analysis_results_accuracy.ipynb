# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rankings = pd.read_csv("../results/techniques_accuracy_evaluation_total.csv")
rankings
# Out:
#                dataset  ranking_eval  \
# 0            acustic_0      0.000000
# 1            acustic_1      0.285714
# 2            acustic_2      0.142857
# 3            acustic_3      0.285714
# 4            acustic_4      0.428571
# ...                ...           ...
# 3035  qualitywhite_375      0.571429
# 3036  qualitywhite_376      0.571429
# 3037  qualitywhite_377      0.571429
# 3038  qualitywhite_378      0.571429
# 3039  qualitywhite_379      0.714286
#
#                                       ranking_real  \
# 0     ['IQR' 'ZSB' 'ISO' 'LOF' 'STD' 'PERC' 'KNN']
# 1     ['IQR' 'ZSB' 'ISO' 'STD' 'LOF' 'PERC' 'KNN']
# 2     ['IQR' 'ISO' 'ZSB' 'STD' 'LOF' 'PERC' 'KNN']
# 3     ['IQR' 'ZSB' 'ISO' 'STD' 'LOF' 'PERC' 'KNN']
# 4     ['IQR' 'ZSB' 'ISO' 'STD' 'LOF' 'PERC' 'KNN']
# ...                                            ...
# 3035  ['KNN' 'ZSB' 'IQR' 'ISO' 'LOF' 'PERC' 'STD']
# 3036  ['KNN' 'ZSB' 'IQR' 'ISO' 'LOF' 'PERC' 'STD']
# 3037  ['KNN' 'ZSB' 'IQR' 'ISO' 'LOF' 'PERC' 'STD']
# 3038  ['KNN' 'ZSB' 'IQR' 'ISO' 'LOF' 'PERC' 'STD']
# 3039  ['ZSB' 'KNN' 'IQR' 'ISO' 'LOF' 'PERC' 'STD']
#
#                                       ranking_pred  \
# 0     ['KNN' 'ISO' 'IQR' 'ZSB' 'LOF' 'STD' 'PERC']
# 1     ['KNN' 'IQR' 'ISO' 'ZSB' 'LOF' 'STD' 'PERC']
# 2     ['KNN' 'IQR' 'ISO' 'ZSB' 'LOF' 'STD' 'PERC']
# 3     ['KNN' 'IQR' 'ISO' 'ZSB' 'LOF' 'STD' 'PERC']
# 4     ['IQR' 'KNN' 'ISO' 'ZSB' 'LOF' 'STD' 'PERC']
# ...                                            ...
# 3035  ['ZSB' 'IQR' 'KNN' 'ISO' 'LOF' 'PERC' 'STD']
# 3036  ['ZSB' 'IQR' 'KNN' 'ISO' 'LOF' 'PERC' 'STD']
# 3037  ['ZSB' 'IQR' 'KNN' 'ISO' 'LOF' 'PERC' 'STD']
# 3038  ['ZSB' 'IQR' 'KNN' 'ISO' 'LOF' 'PERC' 'STD']
# 3039  ['ZSB' 'IQR' 'KNN' 'ISO' 'LOF' 'PERC' 'STD']
#
#                                              value_real  \
# 0     [0.94668515 0.94213376 0.85549728 0.4369114  0...
# 1     [0.98051448 0.94161018 0.93254889 0.60297033 0...
# 2     [0.98249755 0.93626052 0.93461326 0.59084037 0...
# 3     [0.9906242  0.94368969 0.93097904 0.61406362 0...
# 4     [0.99186406 0.94633037 0.9358617  0.59613261 0...
# ...                                                 ...
# 3035  [0.98602777 0.98357832 0.94156047 0.33414665 0...
# 3036  [0.9864381  0.96374265 0.91884026 0.33155197 0...
# 3037  [0.98621598 0.98238981 0.94784339 0.33307814 0...
# 3038  [0.986172   0.98529906 0.95246579 0.33320944 0...
# 3039  [0.98623457 0.98512015 0.97143576 0.33342575 0...
#
#                                              value_pred
# 0     [0.95612376 0.75679036 0.67490417 0.61197534 0...
# 1     [0.99510856 0.92103187 0.74949658 0.69058917 0...
# 2     [0.99479746 0.9341351  0.72246277 0.71657537 0...
# 3     [0.99380709 0.95534138 0.73971911 0.67789417 0...
# 4     [0.96051332 0.9090576  0.84106452 0.67604196 0...
# ...                                                 ...
# 3035  [0.95495559 0.91439826 0.64380003 0.35371808 0...
# 3036  [0.95597994 0.91642601 0.66762169 0.34159492 0...
# 3037  [0.95756676 0.91771528 0.64629067 0.35988397 0...
# 3038  [9.68001359e-01 9.39364656e-01 6.63459381e-01 ...
# 3039  [9.69054673e-01 9.40209146e-01 6.60415706e-01 ...
#
# [3040 rows x 6 columns]

# %%
dd = rankings.ranking_real

# %%
def get_ranking_array(s):
    s = s.replace(".        ]",".0]")
    s = s.replace("   "," ")
    s = s.replace("  "," ")
    s = s.replace(" ]","]")
    s = s.replace("\'","")
    s = s.replace("[","")
    s = s.replace("]","")
    s = s.split(" ")
    s = np.array(s)
    return s

# %%
res = []
for i in range(0,len(dd)):
    res.append(get_ranking_array(dd[i]))

# %%
df = pd.DataFrame(res)

# %%
df
# Out:
#         0    1    2    3    4     5    6
# 0     IQR  ZSB  ISO  LOF  STD  PERC  KNN
# 1     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# 2     IQR  ISO  ZSB  STD  LOF  PERC  KNN
# 3     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# 4     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# ...   ...  ...  ...  ...  ...   ...  ...
# 3035  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3036  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3037  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3038  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3039  ZSB  KNN  IQR  ISO  LOF  PERC  STD
#
# [3040 rows x 7 columns]

# %%
#df.to_csv("../results/rankings_od_real.csv",header=None,index=None)

# %%
df = pd.read_csv("../results/rankings_od_real.csv")
df
# Out:
#         1    2    3    4    5     6    7
# 0     IQR  ZSB  ISO  LOF  STD  PERC  KNN
# 1     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# 2     IQR  ISO  ZSB  STD  LOF  PERC  KNN
# 3     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# 4     IQR  ZSB  ISO  STD  LOF  PERC  KNN
# ...   ...  ...  ...  ...  ...   ...  ...
# 3035  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3036  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3037  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3038  KNN  ZSB  IQR  ISO  LOF  PERC  STD
# 3039  ZSB  KNN  IQR  ISO  LOF  PERC  STD
#
# [3040 rows x 7 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
max_count = df.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df.columns))

for i, column in enumerate(df.columns):
    sns.countplot(y=column, data=df, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)  # Impostiamo il limite dell'asse x

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

melted_df = df.melt(var_name='Position', value_name='Technique')

melted_df['Position'] = melted_df['Position'].apply(lambda x: df.columns.get_loc(x) + 1)

plt.figure(figsize=(15, 8))
sns.boxplot(x='Technique', y='Position', data=melted_df, order=sorted(melted_df.Technique.unique()))
plt.xticks(rotation=90)
plt.title('Distribution of the positions of the techniques')
plt.xlabel('Data Imputation')
plt.ylabel('Ranking Position')
plt.gca().invert_yaxis()
plt.show()

# %%
dd = rankings.ranking_pred

def get_ranking_array(s):
    s = s.replace(".        ]", ".0]")
    s = s.replace("   ", " ")
    s = s.replace("  ", " ")
    s = s.replace(" ]", "]")
    s = s.replace("\'", "")
    s = s.replace("[", "")
    s = s.replace("]", "")
    s = s.split(" ")
    s = np.array(s)
    return s

res = []
for i in range(0, len(dd)):
    res.append(get_ranking_array(dd[i]))

df1 = pd.DataFrame(res)
#df1.to_csv("../results/rankings_od_pred.csv",header=None,index=None)

# %%
df1 = pd.read_csv("../results/rankings_od_pred.csv")

# %%
### confronto le predizioni con i rankings reali

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
max_count = df.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df.columns))

for i, column in enumerate(df.columns):
    sorted_counts = df[column].value_counts().sort_index()
    sns.barplot(y=sorted_counts.index, x=sorted_counts.values, ax=axes[i], palette=colors)
    #sns.countplot(y=column, data=df, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)

plt.tight_layout()
plt.show()






sns.set(style="whitegrid")
max_count = df1.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df1.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df1.columns))

for i, column in enumerate(df1.columns):
    sorted_counts = df[column].value_counts().sort_index()
    sns.barplot(y=sorted_counts.index, x=sorted_counts.values, ax=axes[i], palette=colors)
    #sns.countplot(y=column, data=df1, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)

plt.tight_layout()
plt.show()
