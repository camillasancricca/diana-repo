# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

# %%
suggested
# Out:
#         dimension_1   dimension_2                 imp_1                 imp_2  \
# 0          accuracy  completeness       impute_standard       impute_standard
# 1          accuracy  completeness       impute_standard  impute_random_forest
# 2          accuracy  completeness       impute_standard         impute_median
# 3          accuracy  completeness       impute_standard       impute_standard
# 4      completeness      accuracy           impute_mode       impute_standard
# ...             ...           ...                   ...                   ...
# 30235      accuracy  completeness  impute_random_forest       impute_standard
# 30236      accuracy  completeness         impute_median           impute_mode
# 30237      accuracy  completeness       impute_standard       impute_standard
# 30238  completeness      accuracy       impute_standard           impute_mode
# 30239      accuracy  completeness            impute_knn            impute_knn
#
#                       imp_3            imp_4                 imp_5  \
# 0           impute_standard  impute_standard       impute_standard
# 1           impute_standard  impute_standard  impute_random_forest
# 2           impute_standard      impute_mode         impute_median
# 3           impute_standard  impute_standard       impute_standard
# 4               impute_mode      impute_mode       impute_standard
# ...                     ...              ...                   ...
# 30235  impute_random_forest  impute_standard       impute_standard
# 30236         impute_median      impute_mode       impute_standard
# 30237       impute_standard  impute_standard       impute_standard
# 30238       impute_standard      impute_mode           impute_mode
# 30239            impute_knn       impute_knn            impute_knn
#
#                       imp_6                 imp_7  od_1  ...      imp_col_2  \
# 0           impute_standard       impute_standard   NaN  ...            Age
# 1           impute_standard  impute_random_forest   NaN  ...            Age
# 2               impute_mode         impute_median   NaN  ...            Age
# 3           impute_standard       impute_standard   NaN  ...            Age
# 4               impute_mode       impute_standard   NaN  ...            Age
# ...                     ...                   ...   ...  ...            ...
# 30235  impute_random_forest       impute_standard   NaN  ...  SpendingScore
# 30236         impute_median       impute_standard   NaN  ...  SpendingScore
# 30237       impute_standard       impute_standard   NaN  ...  SpendingScore
# 30238       impute_standard           impute_mode   NaN  ...  SpendingScore
# 30239            impute_knn            impute_knn   NaN  ...  SpendingScore
#
#         imp_col_3   imp_col_4   imp_col_5      imp_col_6   imp_col_7  \
# 0         Graduat  Profession  Experience  SpendingScore  FamilySize
# 1         Graduat  Profession  Experience  SpendingScore  FamilySize
# 2         Graduat  Profession  Experience  SpendingScore  FamilySize
# 3         Graduat  Profession  Experience  SpendingScore  FamilySize
# 4         Graduat  Profession  Experience  SpendingScore  FamilySize
# ...           ...         ...         ...            ...         ...
# 30235  Experience  Profession     Graduat            Age      Gender
# 30236  Experience  Profession     Graduat            Age      Gender
# 30237  Experience  Profession     Graduat            Age      Gender
# 30238  Experience  Profession     Graduat            Age      Gender
# 30239  Experience  Profession     Graduat            Age      Gender
#
#                 algorithm perf_dirty    perf_1    perf_2
# 0            DecisionTree   0.778336  0.766231  0.766132
# 1      LogisticRegression   0.810384  0.813225  0.812518
# 2                     KNN   0.778718  0.794066  0.776872
# 3            RandomForest   0.815060  0.804800  0.808580
# 4                AdaBoost   0.811262  0.816557  0.810667
# ...                   ...        ...       ...       ...
# 30235  LogisticRegression   0.812775  0.804149  0.806541
# 30236                 KNN   0.780134  0.768460  0.765466
# 30237        RandomForest   0.810086  0.800954  0.782292
# 30238            AdaBoost   0.825792  0.818772  0.807141
# 30239                 SVC   0.791944  0.785824  0.769159
#
# [30240 rows x 27 columns]

# %%
models = ['DecisionTree','LogisticRegression','KNN','RandomForest','AdaBoost','SVC']

# %%
models = ['LogisticRegression']

# %%
for algorithm in models:

    sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
    suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

    suggested = suggested[suggested.algorithm == algorithm]
    sample = sample[['dimension_1', 'dimension_2', 'imp_1', 'imp_2', 'imp_3', 'imp_4',
           'imp_5', 'imp_6', 'imp_7', 'od_1', 'od_2', 'od_3', 'od_4', 'od_5',
           'od_6', 'od_7', 'imp_col_1', 'imp_col_2', 'imp_col_3', 'imp_col_4',
           'imp_col_5', 'imp_col_6', 'imp_col_7', algorithm + '_dirty', algorithm + '_1', algorithm + '_2']]

    original_perf = {
            'DecisionTree': 0.8730314885952215,
            'LogisticRegression': 0.7166503552028867,
            'KNN': 0.81529491393676,
            'RandomForest': 0.8975431406130385,
            'AdaBoost': 0.6669934606506549,
            'SVC': 0.7537471482401658
        }

    x = [sample[algorithm + '_2']]
    y = [suggested.perf_2]

    plt.title(algorithm)

    plt.hist(x, label='ALL', color='royalblue')
    plt.hist(y, label='SUGGESTED', color='red')

    plt.axvline(x=np.median(y), color='red', label='median suggested')
    plt.axvline(x=np.median(x), color='black', label='median all')

    #plt.axvline(x=np.percentile(y, 25), color='red', label='1Q suggested', linestyle='dashed')
    #plt.axvline(x=np.percentile(x, 25), color='black', label='1Q all', linestyle='dashed')

    #plt.axvline(x=np.percentile(y, 75), color='red', label='3Q suggested', linestyle='dashed')
    #plt.axvline(x=np.percentile(x, 75), color='black', label='3Q all', linestyle='dashed')

    plt.axvline(x=original_perf[algorithm], color='darkorange', label='dirty')

    #plt.legend(loc='upper right')
    plt.ylim(0,120000)

    plt.savefig("/Users/camillasancricca/Desktop/" + algorithm + "people.pdf", bbox_inches='tight')
    plt.show()

# %%
for algorithm in models:

    sample = pd.read_csv('schedule/compiled_sample_schedule.csv')
    suggested = pd.read_csv('schedule/compiled_suggested_schedule.csv')

    suggested = suggested[suggested.algorithm == algorithm]
    sample = sample[['dimension_1', 'dimension_2', 'imp_1', 'imp_2', 'imp_3', 'imp_4',
           'imp_5', 'imp_6', 'imp_7', 'od_1', 'od_2', 'od_3', 'od_4', 'od_5',
           'od_6', 'od_7', 'imp_col_1', 'imp_col_2', 'imp_col_3', 'imp_col_4',
           'imp_col_5', 'imp_col_6', 'imp_col_7', algorithm + '_dirty', algorithm + '_1', algorithm + '_2']]

    original_perf = {
            'DecisionTree': 0.8730314885952215,
            'LogisticRegression': 0.7166503552028867,
            'KNN': 0.81529491393676,
            'RandomForest': 0.8975431406130385,
            'AdaBoost': 0.6669934606506549,
            'SVC': 0.7537471482401658
        }

    x = [sample[algorithm + '_2']]
    y = [suggested.perf_2]

    plt.title(algorithm)

    plt.hist(x, label='ALL', color='royalblue')
    plt.hist(y, label='SUGGESTED', color='red')

    plt.axvline(x=np.median(y), color='red', label='median suggested')
    plt.axvline(x=np.median(x), color='black', label='median all')

    plt.axvline(x=np.percentile(y, 25), color='red', label='1Q suggested', linestyle='dashed')
    plt.axvline(x=np.percentile(x, 25), color='black', label='1Q all', linestyle='dashed')

    plt.axvline(x=np.percentile(y, 75), color='red', label='3Q suggested', linestyle='dashed')
    plt.axvline(x=np.percentile(x, 75), color='black', label='3Q all', linestyle='dashed')

    #plt.axvline(x=original_perf[algorithm], color='darkorange', label='dirty')

    plt.legend(loc='upper right')
    plt.savefig("/Users/camillasancricca/Desktop/" + algorithm + "2.png", bbox_inches='tight')
    plt.show()
