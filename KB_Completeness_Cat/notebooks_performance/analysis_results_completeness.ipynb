# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
rankings = pd.read_csv("../results/techniques_completeness_evaluation_total.csv")
rankings
# Out:
#                  dataset               model  ranking_eval  \
# 0              abalone_0        DecisionTree         0.125
# 1              abalone_0  LogisticRegression         0.125
# 2              abalone_0                 KNN         0.000
# 3              abalone_0        RandomForest         0.125
# 4              abalone_0            AdaBoost         0.250
# ...                  ...                 ...           ...
# 2095  visualizing_soil_9  LogisticRegression         0.500
# 2096  visualizing_soil_9                 KNN         0.125
# 2097  visualizing_soil_9        RandomForest         0.500
# 2098  visualizing_soil_9            AdaBoost         0.500
# 2099  visualizing_soil_9                 SVC         0.250
#
#                                            ranking_real  \
# 0     ['impute_logistic_regression' 'impute_random_f...
# 1     ['impute_logistic_regression' 'impute_random_f...
# 2     ['impute_logistic_regression' 'impute_random' ...
# 3     ['impute_random_forest' 'impute_logistic_regre...
# 4     ['impute_standard' 'impute_mode' 'impute_rando...
# ...                                                 ...
# 2095  ['impute_random_forest' 'impute_mice' 'impute_...
# 2096  ['impute_random_forest' 'impute_mice' 'impute_...
# 2097  ['impute_random_forest' 'impute_mice' 'impute_...
# 2098  ['impute_random_forest' 'impute_mice' 'impute_...
# 2099  ['impute_random_forest' 'impute_knn' 'impute_m...
#
#                                            ranking_pred  \
# 0     ['impute_standard' 'impute_kproto' 'impute_mod...
# 1     ['impute_standard' 'impute_random_forest' 'imp...
# 2     ['impute_random_forest' 'impute_logistic_regre...
# 3     ['impute_standard' 'impute_random_forest' 'imp...
# 4     ['impute_standard' 'impute_mode' 'impute_kprot...
# ...                                                 ...
# 2095  ['impute_random_forest' 'impute_knn' 'impute_m...
# 2096  ['impute_random_forest' 'impute_knn' 'impute_l...
# 2097  ['impute_random_forest' 'impute_knn' 'impute_m...
# 2098  ['impute_random_forest' 'impute_mice' 'impute_...
# 2099  ['impute_standard' 'impute_knn' 'impute_random...
#
#                                              value_real  \
# 0     [0.21153403 0.21124612 0.21094217 0.21091189 0...
# 1     [0.22512333 0.22346259 0.22003224 0.21978918 0...
# 2     [0.19698441 0.19395516 0.19387145 0.19370697 0...
# 3     [0.22028637 0.21977642 0.21850252 0.21773348 0...
# 4     [0.09865008 0.09865008 0.09865008 0.09865008 0...
# ...                                                 ...
# 2095  [0.99804727 0.99280132 0.99276518 0.9846387  0...
# 2096  [0.99513087 0.99275645 0.99272032 0.98902638 0...
# 2097  [0.99943356 0.99702318 0.99696294 0.99402579 0...
# 2098  [0.99926483 0.99672193 0.99668579 0.99622864 0...
# 2099  [0.97423407 0.96329527 0.96266515 0.94182183 0...
#
#                                              value_pred  perc_completeness
# 0     [0.78797929 0.78104096 0.78101848 0.78073646 0...           0.500287
# 1     [0.77337203 0.77170634 0.76884538 0.76884538 0...           0.500287
# 2     [0.73154144 0.73137178 0.72986687 0.72969646 0...           0.500287
# 3     [0.79601548 0.7921078  0.79135453 0.78989674 0...           0.500287
# 4     [0.7420425  0.74015001 0.74009937 0.73988175 0...           0.500287
# ...                                                 ...                ...
# 2095  [0.81908981 0.81867885 0.81847289 0.81497349 0...           0.050862
# 2096  [0.78446959 0.78413914 0.783886   0.78387115 0...           0.050862
# 2097  [0.84347252 0.8427125  0.84251049 0.84249815 0...           0.050862
# 2098  [0.79205063 0.79185643 0.79159473 0.78781723 0...           0.050862
# 2099  [0.73409749 0.72093635 0.72090095 0.72061666 0...           0.050862
#
# [2100 rows x 8 columns]

# %%
dd = rankings.ranking_real

# %%
def get_ranking_array(s):
    s = s.replace(".        ]",".0]")
    s = s.replace("   "," ")
    s = s.replace("  "," ")
    s = s.replace(" ]","]")
    s = s.replace("\'","")
    s = s.replace("[","")
    s = s.replace("]","")
    s = s.split(" ")
    s = np.array(s)
    return s

# %%
res = []
for i in range(0,len(dd)):
    res.append(get_ranking_array(dd[i]))

# %%
df = pd.DataFrame(res)

# %%
df
# Out:
#                                0                           1                2  \
# 0     impute_logistic_regression        impute_random_forest    impute_kproto
# 1     impute_logistic_regression        impute_random_forest  impute_standard
# 2     impute_logistic_regression               impute_random  impute_standard
# 3           impute_random_forest  impute_logistic_regression    impute_kproto
# 4                impute_standard                 impute_mode    impute_random
# ...                          ...                         ...              ...
# 2095        impute_random_forest                 impute_mice       impute_knn
# 2096        impute_random_forest                 impute_mice       impute_knn
# 2097        impute_random_forest                 impute_mice       impute_knn
# 2098        impute_random_forest                 impute_mice       impute_knn
# 2099        impute_random_forest                  impute_knn      impute_mice
#
#                     3                           4                           5  \
# 0         impute_mode               impute_random                  impute_knn
# 1         impute_mice                  impute_knn               impute_random
# 2         impute_mode               impute_kproto        impute_random_forest
# 3         impute_mode               impute_random             impute_standard
# 4          impute_knn                 impute_mice  impute_logistic_regression
# ...               ...                         ...                         ...
# 2095  impute_standard                 impute_mode  impute_logistic_regression
# 2096      impute_mode  impute_logistic_regression               impute_kproto
# 2097  impute_standard  impute_logistic_regression               impute_kproto
# 2098  impute_standard                 impute_mode  impute_logistic_regression
# 2099  impute_standard               impute_random                 impute_mode
#
#                                6                7
# 0                    impute_mice  impute_standard
# 1                    impute_mode    impute_kproto
# 2                     impute_knn      impute_mice
# 3                     impute_knn      impute_mice
# 4           impute_random_forest    impute_kproto
# ...                          ...              ...
# 2095               impute_kproto    impute_random
# 2096             impute_standard    impute_random
# 2097                 impute_mode    impute_random
# 2098               impute_kproto    impute_random
# 2099  impute_logistic_regression    impute_kproto
#
# [2100 rows x 8 columns]

# %%
df.to_csv("../results/rankings_imputation_real.csv",columns=[0,1,2,3,4,5,6,7],index=None)

# %%
df = pd.read_csv("../results/rankings_imputation_real.csv")
df
# Out:
#                                0                           1                2  \
# 0     impute_logistic_regression        impute_random_forest    impute_kproto
# 1     impute_logistic_regression        impute_random_forest  impute_standard
# 2     impute_logistic_regression               impute_random  impute_standard
# 3           impute_random_forest  impute_logistic_regression    impute_kproto
# 4                impute_standard                 impute_mode    impute_random
# ...                          ...                         ...              ...
# 2095        impute_random_forest                 impute_mice       impute_knn
# 2096        impute_random_forest                 impute_mice       impute_knn
# 2097        impute_random_forest                 impute_mice       impute_knn
# 2098        impute_random_forest                 impute_mice       impute_knn
# 2099        impute_random_forest                  impute_knn      impute_mice
#
#                     3                           4                           5  \
# 0         impute_mode               impute_random                  impute_knn
# 1         impute_mice                  impute_knn               impute_random
# 2         impute_mode               impute_kproto        impute_random_forest
# 3         impute_mode               impute_random             impute_standard
# 4          impute_knn                 impute_mice  impute_logistic_regression
# ...               ...                         ...                         ...
# 2095  impute_standard                 impute_mode  impute_logistic_regression
# 2096      impute_mode  impute_logistic_regression               impute_kproto
# 2097  impute_standard  impute_logistic_regression               impute_kproto
# 2098  impute_standard                 impute_mode  impute_logistic_regression
# 2099  impute_standard               impute_random                 impute_mode
#
#                                6                7
# 0                    impute_mice  impute_standard
# 1                    impute_mode    impute_kproto
# 2                     impute_knn      impute_mice
# 3                     impute_knn      impute_mice
# 4           impute_random_forest    impute_kproto
# ...                          ...              ...
# 2095               impute_kproto    impute_random
# 2096             impute_standard    impute_random
# 2097                 impute_mode    impute_random
# 2098               impute_kproto    impute_random
# 2099  impute_logistic_regression    impute_kproto
#
# [2100 rows x 8 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
max_count = df.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df.columns))

for i, column in enumerate(df.columns):
    sns.countplot(y=column, data=df, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)  # Impostiamo il limite dell'asse x

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

melted_df = df.melt(var_name='Position', value_name='Technique')

melted_df['Position'] = melted_df['Position'].apply(lambda x: df.columns.get_loc(x) + 1)

plt.figure(figsize=(15, 8))
sns.boxplot(x='Technique', y='Position', data=melted_df, order=sorted(melted_df.Technique.unique()))
plt.xticks(rotation=90)
plt.title('Distribution of the positions of the techniques')
plt.xlabel('Data Imputation')
plt.ylabel('Ranking Position')
plt.gca().invert_yaxis()
plt.show()

# %%
dd = rankings.ranking_pred

def get_ranking_array(s):
    s = s.replace(".        ]", ".0]")
    s = s.replace("   ", " ")
    s = s.replace("  ", " ")
    s = s.replace(" ]", "]")
    s = s.replace("\'", "")
    s = s.replace("[", "")
    s = s.replace("]", "")
    s = s.split(" ")
    s = np.array(s)
    return s

res = []
for i in range(0, len(dd)):
    res.append(get_ranking_array(dd[i]))

df1 = pd.DataFrame(res)
df1.to_csv("../results/rankings_imputation_pred.csv",columns=[0,1,2,3,4,5,6,7],index=None)

# %%
df1 = pd.read_csv("../results/rankings_imputation_pred.csv")

# %%
### confronto le predizioni con i rankings reali

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
max_count = df.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df.columns))

for i, column in enumerate(df.columns):
    sorted_counts = df[column].value_counts().sort_index()
    sns.barplot(y=sorted_counts.index, x=sorted_counts.values, ax=axes[i], palette=colors)
    #sns.countplot(y=column, data=df, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)

plt.tight_layout()
plt.show()






sns.set(style="whitegrid")
max_count = df1.apply(pd.Series.value_counts).max().max()
fig, axes = plt.subplots(nrows=1, ncols=len(df1.columns), figsize=(20, 5), sharey=True)
colors = sns.color_palette("hsv", len(df1.columns))

for i, column in enumerate(df1.columns):
    sorted_counts = df[column].value_counts().sort_index()
    sns.barplot(y=sorted_counts.index, x=sorted_counts.values, ax=axes[i], palette=colors)
    #sns.countplot(y=column, data=df1, ax=axes[i], palette=colors)
    axes[i].set_title(column)
    axes[i].set_xlabel('Frequency')
    axes[i].set_ylabel('')
    axes[i].set_xlim(0, max_count)

plt.tight_layout()
plt.show()
